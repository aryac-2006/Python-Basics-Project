# %% [markdown]
# <a href="https://colab.research.google.com/github/aryac-2006/Python-Basics-Project/blob/main/Unique_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
try:
    sentence = input("Enter sentence: ")
    # Split the sentence into words
    words = sentence.split()

    # Store unique words in a set
    unique_words = set(words)

    # Print unique words in sorted order
    print("\nUnique Words: ")
    for word in sorted(unique_words):
        print(word)

    count = len(unique_words)
    print("\nNumber of Unique Words: ", count)

    # Print square of the count using math.pow()
    print("Square of Unique Words: ", math.pow(count, 2))

except Exception as e:
    print(e)
# Out:
# Enter sentence: My name is Arya, i am learning python.
#
# Unique Words:
# Arya,
# My
# am
# i
# is
# learning
# name
# python.
#
# Number of Unique Words:  8
# Square of Unique Words:  64.0
